# %%
import os
cwd = os.getcwd()
cwd

# %%
pip install pdfminer
# Out:
# Collecting pdfminer
#   Downloading pdfminer-20191125.tar.gz (4.2 MB)
# Requirement already satisfied: pycryptodome in c:\users\ja903976\anaconda3\lib\site-packages (from pdfminer) (3.10.1)
# Building wheels for collected packages: pdfminer
#   Building wheel for pdfminer (setup.py): started
#   Building wheel for pdfminer (setup.py): finished with status 'done'
#   Created wheel for pdfminer: filename=pdfminer-20191125-py3-none-any.whl size=6140142 sha256=0618df62d4e05c55aebef1bb07622a2559990a21e77aed7de532831ae7d5a548
#   Stored in directory: c:\users\ja903976\appdata\local\pip\cache\wheels\1c\28\7d\f390b82bb0307deb63ff27a1474fd308ec68ee028cb9ab6283
# Successfully built pdfminer
# Installing collected packages: pdfminer
# Successfully installed pdfminer-20191125
# Note: you may need to restart the kernel to use updated packages.

# %%
import sys
from pdfminer.pdfinterp import PDFResourceManager, PDFPageInterpreter
from pdfminer.pdfpage import PDFPage
from pdfminer.converter import XMLConverter, HTMLConverter, TextConverter
from pdfminer.layout import LAParams
import io

def pdfparser(data):

    fp = open(data, 'rb')
    rsrcmgr = PDFResourceManager()
    retstr = io.StringIO()
    laparams = LAParams()
    device = TextConverter(rsrcmgr, retstr, 
                           laparams=laparams)
    
    # Create a PDF interpreter object.
    interpreter = PDFPageInterpreter(rsrcmgr, device)
    # Process each page contained in the document.

    for page in PDFPage.get_pages(fp):
        interpreter.process_page(page)
        data =  retstr.getvalue()

    return(data)

# %%
mypdf = 'C:/Users/ja903976/OneDrive - BioMarin/Desktop/Studies/BMRN270/270-301/ExternalLab/Covance_ControlledDocs/BioMarin_270-301_Covance_DTS_Final V17.0_01Dec2020_signed.pdf'

output = pdfparser(mypdf)

# %%
output
# Out:
# " \n\nData Transfer Specifications \n\n \n \n\n \n\n \n\n \n \n\nData Transfer Specifications  \n\n \n\nSafety Laboratory Data Plus Specialty Laboratory Data \n\nProtocol:  270-301 \n\nProtocol Description:   \nA Phase 3 Open-Label, Single-Arm Study to Evaluate the Efficacy and \nSafety of BMN 270, an Adeno-Associated Virus Vector–Mediated Gene \nTransfer of Human Factor VIII in Hemophilia A Patients with Residual \nFVIII Levels ≤ 1 IU/dL Receiving Prophylactic FVIII Infusions  \n \n\nVendor:  \n \nData Type: \n \n\nAuthor: \n \nVersion Date: \n \nDocument Version: \n \n\n \n\n \n\n \n\nCovance \n\nSafety data (Chemistry, Hematology, \nCoagulation, Urinalysis). \nSpecialty data (Factor VIII Activity, Factor VIII \nInhibitors, AA, Blood, saliva, semen, urine, stool \nvector shedding, Biomarkers, HCV RNA storage, \nHBV DNA storage, AAV5, HIV, HLA).  \nJason Delosh  \n11Dec2020 \n\n17.0 \n\n\x0c \n\n  Overview .................................................................................................................................... 3 \n\n  Data Transfer Information .......................................................................................................... 4 \n\n  Table and Field Specifications ..................................................................................................... 8 \n\n \n\n Summary of Changes ............................................................................................................... 10 \n\nAPPENDIX 1 – Visit Names ................................................................................................................ 11 \n\nAPPENDIX 2 – Laboratory Test Identifiers, Short and Long Names .................................................... 18 \n\nAPPENDIX 3 – Laboratory Names ...................................................................................................... 31 \n\nAPPENDIX 4 – Planned Timepoints ................................................................................................... 31 \n\nAPPENDIX 5 – Signature Page...…………………………………………………………………………………….…………………32 \n\n \n\n \n\nProtocol Number: 270-301 \nVersion Number: v17.0 11DEC2020 \n\nPage 2 of 43 \n\n\x0c  Overview \n\nThis document describes  the  requirements for  the  transfer of  Safety laboratory data plus specialty \nLaboratory data.  Covance will be responsible for analysis and generation of results for the following \ncategories: Chemistry, Hematology, Urinalysis, Coagulation (see Appendix 2 for details of all tests). \n \nCovance will transfer data file, the MS Excel with the FVIII Genotyping lab results separately.  \n \nIn addition, Covance will be responsible for receiving all samples and results from individual \nSpecialty labs and reporting them in the data transfer. Details of individual labs and samples \nthat will be sent to Covance are as follows: \n \n\nLAB NAME \n\nTEST NAME \n\nColorado Coag Lab  \nCorp \n\nFVIII ACTIVITY ONE-STAGE  \nFVIII ACTIVITY CHROMOGENIC \nFVIII INHIBITOR LEVEL (EXP) \nFVIII INHIBITOR LEVEL REPEAT \nVON WILLERBRAND FACTOR ANTIGEN \n\nEurofins \n\nFVIII TOTAL ANTIBODY TITER \nAAV5 TOTAL ANTIBODY POST-DOSE \n\nCovance Harrogate \n\nPrecision for \nMedicine \n\nBLOOD VECTOR SHEDDING \nSALIVA VECTOR SHEDDING \nSEMEN VECTOR SHEDDING \nSEMEN FRACTIONATION \nURINE VECTOR SHEDDING \nSTOOL VECTOR SHEDDING \n\nSM / EXPL PLASMA BIOMARKER \nSM / EXPL CELLS BIOMARKER \nSM / EXPL SERUM BIOMARKER \nSM / EXPL RED BLOOD CELLS \nSM / PBMC ALIQUOTS \nSM / DNA EXTRACTION \nSM / HCV RNA STORAGE \nSM / HBV DNA STORAGE \nSM / FVIII COAG EXPLORATORY \n\nCONTACT DETAILS \n\n8490 Upland Drive, Suite 100 \n80112 Englewood \nUSA \nTel: +1 800 4449111 \nFax: +1 720 5684313 \nContact:  Paige Macy    \nPhone +1720-568-4320   \nEmail:  macyp@labcorp.com \n\n90 Park Drive, Milton Park \nOX14 4RY Abingdon \nUnited Kingdom \nTel: +44 1235 444141 \nContact: Joanne Heredge          \nEmail: joanneheredge@eurofins.com \nManaging Director: Antonio Marques  \nE ...
